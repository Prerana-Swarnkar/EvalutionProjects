# %%
#Import Libraries
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df_hr=pd.read_csv('HR_analytics.csv')
df_hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df_hr.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df_hr.shape
# Out:
# (1470, 35)

# %%
df_hr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Observation:
#
#     1. Dataset has 1470 rows and 35 columns.
#
#     2. df_hr.columns returns the name of all the columns.

# %%
df_hr.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# Obsservation:
#
#     1.Attrition,BusinessTravel,Department,EducationField,Gender,JobRole,MaritalStatus,Over18,OverTime, are object type.
#
#     2. Remaing all are int type.

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Observation:
#
#     1. Info function shows range index from 0-1469,total number of columns,count and their respective datatypes.

# %% [markdown]
# # Statics summary

# %%
df_hr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Observation:
#
#     1. There is huge diffrence in max value and 75% value in following columns(Employee Number,Year at Company ,Year at Comapny,YearsinCurrentRole,YearsSincePromotion,YearWithCurrManagers) may have outliers.
#
#     2. Max std is for EmployeeNumber.

# %%
#Check the unique value and cont of object type.
for column in df_hr.columns:
    if df_hr[column].dtypes == object:
        print(str(column)+ ':' + str(df_hr[column].unique()))
        print(df_hr[column].value_counts())
        print('---------------------------------------')
# Out:
# Attrition:['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# ---------------------------------------
# BusinessTravel:['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# ---------------------------------------
# Department:['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# ---------------------------------------
# EducationField:['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ---------------------------------------
# Gender:['Female' 'Male']
# Male      882
# Female    588
# ...

# %% [markdown]
# Observation:
#
#     1. All the object type data type has its unique value ex. Attrition has 2 values 'yes' and 'No' and no of counts.

# %%
df_hr['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# Observation:
#
#     1. 1233 employess are still working.
#     2. 237 employees leave the job.

# %%
#check null values in dataset
df_hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#For More clearity plot a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(df_hr.isnull())

# %% [markdown]
# Observation:
#     1.There is no null values Present in Dataset.

# %% [markdown]
# # Check the Correlation between variables

# %%
df_corr=df_hr.corr()
df_corr
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
#For batter understanding Plot a heatmap of correlation metrix 
plt.figure(figsize=(14,14))
sns.heatmap(df_corr,annot=True, fmt='.0%')

# %% [markdown]
# Observation:
#     1.Age,MonthlyIncome,PercentSalaryHike,PerformanceRating,TotalWorkingYears,YearsAtCompany,JobLevel,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager correlate strongly.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univariant Analysis

# %%
plt.figure(figsize=(15,10))
lab = list(df_hr['Attrition'].unique())
chart = sns.countplot(x="Attrition",hue="Attrition",data=df_hr)

# %% [markdown]
# Observation:
#
#     1. 1233 employees still working in office.
#
#     2. 237 employees left the office

# %%
plt.figure(figsize=(15,10))
lab = list(df_hr['Gender'].unique())
chart = sns.countplot(x="Gender",hue="Attrition",data=df_hr)

# %% [markdown]
# Observation:
#     1. this plot shows nunber of employess according to gender.

# %%
plt.figure(figsize=(15,10))
lab = list(df_hr['Department'].unique())
chart = sns.countplot(x="Department",hue="Attrition",data=df_hr)

# %%
plt.figure(figsize=(15,10))
lab = list(df_hr['JobRole'].unique())
chart = sns.countplot(x="JobRole",hue="Attrition",data=df_hr)
chart.set_xticklabels(labels=lab, rotation=90)
# Out:
# [Text(0, 0, 'Sales Executive'),
#  Text(0, 0, 'Research Scientist'),
#  Text(0, 0, 'Laboratory Technician'),
#  Text(0, 0, 'Manufacturing Director'),
#  Text(0, 0, 'Healthcare Representative'),
#  Text(0, 0, 'Manager'),
#  Text(0, 0, 'Sales Representative'),
#  Text(0, 0, 'Research Director'),
#  Text(0, 0, 'Human Resources')]

# %%
plt.figure(figsize=(15,10))
lab = list(df_hr['MaritalStatus'].unique())
chart = sns.countplot(x="MaritalStatus",hue="Attrition",data=df_hr)

# %%
plt.figure(figsize=(30,15))
sns.countplot(x='Age',hue='Attrition',data=df_hr)
plt.ylabel("No of Employees")
plt.xlabel("Age of Employees")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Observation:
#
#     1. Employees of Age 34,35 still working on Company.
#     2. Employees of Age 29,31 leave the company

# %%
plt.figure(figsize=(15,8))
df_hr['Age'].plot.hist(bins=20)
plt.title("Histogram of  Employee Age")
plt.show()

# %%
plt.figure(figsize=(15,8))
df_hr['MonthlyIncome'].plot.hist(bins=20)
plt.title("Histogram of  Employee Job level")
plt.show()

# %%
plt.figure(figsize=(15,8))
df_hr['TotalWorkingYears'].plot.hist(bins=20)
plt.title("Histogram of  Employee Total Working Year")
plt.show()

# %%
#All column histogram in one place
df_hr.hist(figsize=(18,18))
plt.show()

# %% [markdown]
# Observation:
#     1.Average age frequancy of employess is 30 in company.
#
#     2. Average Daily Rate frequancy is 500.
#
#     3.Average Distance from home is lies between 0 to 5.
#
#     4. Average frequancy of monthly Income is below 5000.

# %%
sns.set(style='whitegrid')
sns.violinplot(df_hr['Age'])
plt.show()

# %%
sns.set(style='whitegrid')
sns.violinplot(df_hr['MonthlyIncome'])
plt.show()

# %% [markdown]
# observation:
#
#     1. Max age of emlloyees is between 30-40 years.
#     2. Max MonthlyIncome is 5000 or more then 5000.

# %% [markdown]
# # Bivariant Analysis

# %%
sns.set(style='white')
plt.scatter(df_hr['Age'],df_hr['MonthlyIncome'])
plt.xlabel('Age')
plt.ylabel('MonthlyIncome')
plt.title("Scatter plot Age vs MonthlyIncome")
plt.show()

# %%
sns.barplot(x='Attrition',y='Age',data=df_hr)

# %%
sns.barplot(x='Attrition',y='MonthlyIncome',data=df_hr)

# %%
sns.barplot(x='Attrition',y='JobLevel',data=df_hr)

# %%
sns.barplot(x='Attrition',y='TotalWorkingYears',data=df_hr)

# %% [markdown]
# # Plotting Outliers

# %%
df_hr.plot(kind='box',subplots=True,layout=(6,6),fontsize=8,figsize=(12,12))
# Out:
# Age                            AxesSubplot(0.125,0.772143;0.110714x0.107857)
# DailyRate                   AxesSubplot(0.257857,0.772143;0.110714x0.107857)
# DistanceFromHome            AxesSubplot(0.390714,0.772143;0.110714x0.107857)
# Education                   AxesSubplot(0.523571,0.772143;0.110714x0.107857)
# EmployeeCount               AxesSubplot(0.656429,0.772143;0.110714x0.107857)
# EmployeeNumber              AxesSubplot(0.789286,0.772143;0.110714x0.107857)
# EnvironmentSatisfaction        AxesSubplot(0.125,0.642714;0.110714x0.107857)
# HourlyRate                  AxesSubplot(0.257857,0.642714;0.110714x0.107857)
# JobInvolvement              AxesSubplot(0.390714,0.642714;0.110714x0.107857)
# JobLevel                    AxesSubplot(0.523571,0.642714;0.110714x0.107857)
# JobSatisfaction             AxesSubplot(0.656429,0.642714;0.110714x0.107857)
# MonthlyIncome               AxesSubplot(0.789286,0.642714;0.110714x0.107857)
# ...

# %% [markdown]
# Observation:
#     1.Outliers are Present in MonthlyIncome,NumCompanyWorked,StockOptionalLevel,TotalWorkingYears,YearsAtCompany,YearsinCurrentRole,YearsSinceLastPromotion,YearsWithCurrentManager

# %%
#check the distribution of skewness
for i in df_hr.describe().columns:
        plt.figure()
        sns.distplot(df_hr[i])

# %% [markdown]
# Observation:
#     1. Right skewness is present in DistanceFromHome,JobLevel,MonthlyIncome,NumCompaniesWorked,PercentSalaryHike,YearsAtCompany,YearsinCurrentRole,YearsSinceLastPromotion,YearwithCurrManager

# %%
#Treating Skewness via log method

for col in df_hr.describe().columns:
    if df_hr[col].skew()>0.55:
        df_hr[col]=np.log1p(df_hr[col])

# %%
#checking Skewness of Data
df_hr.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome           -0.029121
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobSatisfaction            -0.329672
# MonthlyIncome               0.286448
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.092896
# PercentSalaryHike           0.513543
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.271963
# TotalWorkingYears          -0.622175
# TrainingTimesLastYear      -1.075852
# WorkLifeBalance            -0.552480
# YearsAtCompany             -0.207708
# YearsInCurrentRole         -0.383498
# YearsSinceLastPromotion     0.718805
# ...

# %%
#Transform the data (Transform non-numerical into numerical col)
from sklearn.preprocessing import LabelEncoder

for column in df_hr.columns:
    if df_hr[column].dtype == np.number:
        continue
    df_hr[column] = LabelEncoder().fit_transform(df_hr[column])

# %%
df_hr
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      23          1               2        624           2          0.693147
# 1      31          0               1        113           1          2.197225
# 2      19          1               2        805           1          1.098612
# 3      15          0               1        820           1          1.386294
# 4       9          0               2        312           1          1.098612
# ...   ...        ...             ...        ...         ...               ...
# 1465   18          0               1        494           1          3.178054
# 1466   21          0               2        327           1          1.945910
# 1467    9          0               2         39           1          1.609438
# 1468   31          0               1        579           2          1.098612
# 1469   16          0               2        336           1          2.197225
#
# ...

# %% [markdown]
# Observation:
#     1.Skewness is Present in MonthlyIncome,JobLevel,YearsAtCompany,YearsSinceLastPromotion,TotalWorkingYears,PerformanceRating,NumCompaniesWorked .

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df_hr))
z
# Out:
# array([[0.4463504 , 2.28090588, 0.59004834, ..., 0.29061127, 0.97334237,
#         0.54799589],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.88267046, 0.11727147,
#         0.90492352],
#        [0.008343  , 2.28090588, 0.59004834, ..., 1.73678265, 0.97334237,
#         1.67504313],
#        ...,
#        [1.08667552, 0.4384223 , 0.59004834, ..., 0.352871  , 0.97334237,
#         0.04493464],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.71446221, 0.97334237,
#         1.05105714],
#        [0.32016256, 0.4384223 , 0.59004834, ..., 0.00951942, 0.11727147,
#         0.311993  ]])

# %%
thershold=3
print(np.where(z<3))
# Out:
# (array([   0,    0,    0, ..., 1469, 1469, 1469], dtype=int64), array([ 0,  1,  2, ..., 32, 33, 34], dtype=int64))

# %%
df_hr_new=df_hr[(z<3).all(axis=1)]
print(df_hr.shape, '\t',df_hr_new.shape)
# Out:
# (1470, 35) 	 (0, 35)

# %%
#Drop usless information

df_hr_new = df_hr.drop(columns=['EmployeeCount','PerformanceRating','StandardHours','Over18','EmployeeNumber'])
df_hr_new.head(7)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   23          1               2        624           2          0.693147
# 1   31          0               1        113           1          2.197225
# 2   19          1               2        805           1          1.098612
# 3   15          0               1        820           1          1.386294
# 4    9          0               2        312           1          1.098612
# 5   14          0               1        572           1          1.098612
# 6   41          0               2        770           1          1.386294
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          1               1                        1       0  ...
# 1          0               1                        2       1  ...
# 2          1               4                        3       1  ...
# 3          3               1                        3       0  ...
# ...

# %% [markdown]
# Observation:
#     1. After deletion of 5 columns only 30 columns left

# %% [markdown]
# EDA Process is End

# %% [markdown]
# # Model Trainning

# %%
#saprating into input and output variables

df_x= df_hr_new.drop(columns=['Attrition'])

# %%
y=pd.DataFrame(df_hr_new['Attrition'])
y.tail()
# Out:
#       Attrition
# 1465          0
# 1466          0
# 1467          0
# 1468          0
# 1469          0

# %%
#Scalling the input variable
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#Again check skewness
x.skew()
# Out:
# Age                         0.413286
# BusinessTravel             -1.439006
# DailyRate                   0.000930
# Department                  0.172231
# DistanceFromHome           -0.029121
# Education                  -0.289681
# EducationField              0.550371
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.286448
# MonthlyRate                 0.012315
# NumCompaniesWorked          0.092896
# OverTime                    0.964489
# PercentSalaryHike           0.513543
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.271963
# TotalWorkingYears          -0.622175
# TrainingTimesLastYear      -1.075852
# WorkLifeBalance            -0.552480
# ...

# %%
#Spliting The Data in Train and Target
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
print(x_train.shape, '\t', x_test.shape)
# Out:
# (1176, 29) 	 (294, 29)

# %%
print(y_train.shape, '\t', y_test.shape)
# Out:
# (1176, 1) 	 (294, 1)

# %%
#importing our Models library
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
#import Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
#Using Algorithms via loop

model=[LogisticRegression(),KNeighborsClassifier(),DecisionTreeClassifier()]
for m in model:
    m.fit(x_train,y_train)
    print('Score of',m,'is:',m.score(x_train,y_train))
    predmodel=m.predict(x_test)
    print('Metrics')
    print('accuracy_score :',accuracy_score(y_test,predmodel))
    print('confusion_matrix :',confusion_matrix(y_test,predmodel))
    print('classification_report:',classification_report(y_test,predmodel))
    print('-----------------------------------------------------------')
    print('\n')
# Out:
# Score of LogisticRegression() is: 0.8758503401360545
# Metrics
# accuracy_score : 0.8843537414965986
# confusion_matrix : [[247   8]
#  [ 26  13]]
# classification_report:               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94       255
#            1       0.62      0.33      0.43        39
#
#     accuracy                           0.88       294
#    macro avg       0.76      0.65      0.68       294
# weighted avg       0.87      0.88      0.87       294
#
# -----------------------------------------------------------
#
#
# Score of KNeighborsClassifier() is: 0.8741496598639455
# Metrics
# accuracy_score : 0.8707482993197279
# confusion_matrix : [[253   2]
#  [ 36   3]]
# classification_report:               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       255
#            1       0.60      0.08      0.14        39
#
#     accuracy                           0.87       294
# ...

# %%
#Using SVR Algorithm
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv= SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.09655284547180198
# 0.8467511357569001
# 0.8045060980731897

# %% [markdown]
# Observation:
#     1. best model for this problem is LogisticRegression.

# %%
#cross validation
from sklearn.model_selection import cross_val_score
lg=LogisticRegression()
scores = cross_val_score(lg,x,y,cv=5).mean()
print(scores)
# Out:
# 0.8761904761904761

# %% [markdown]
# # Using Esemble Technique to Boostup Score

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=25,random_state=60)
rf.fit(x_train,y_train)
print('Score',rf.score(x_train,y_train))
rfpred=rf.predict(x_test)
print('\n')
print('accuracy_score :',accuracy_score(y_test,rfpred))
print('confusion_matrix :',confusion_matrix(y_test,rfpred))
print('classification_report:',classification_report(y_test,rfpred))
# Out:
# Score 0.9982993197278912
#
#
# accuracy_score : 0.8673469387755102
# confusion_matrix : [[251   4]
#  [ 35   4]]
# classification_report:               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       255
#            1       0.50      0.10      0.17        39
#
#     accuracy                           0.87       294
#    macro avg       0.69      0.54      0.55       294
# weighted avg       0.83      0.87      0.83       294

# %%
#using Ada Boost
from sklearn.ensemble import AdaBoostClassifier
lg=LogisticRegression()

adb=AdaBoostClassifier(base_estimator=lg,n_estimators=22,learning_rate=0.1,random_state=70)
adb.fit(x_train,y_train)
print('Score',adb.score(x_train,y_train))
predadb=adb.predict(x_test)
print('\n')
print('accuracy_score :',accuracy_score(y_test,predadb))
print('confusion_matrix :',confusion_matrix(y_test,predadb))
print('classification_report:',classification_report(y_test,predadb))
# Out:
# Score 0.8392857142857143
#
#
# accuracy_score : 0.8673469387755102
# confusion_matrix : [[255   0]
#  [ 39   0]]
# classification_report:               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       255
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.87       294
#    macro avg       0.43      0.50      0.46       294
# weighted avg       0.75      0.87      0.81       294

# %%
#Saving Adaboost Model
import joblib
joblib.dump(rf,'Avacado_avirageprice.pkl')
