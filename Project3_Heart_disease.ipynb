# %%
#Import Libraries
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df_hd=pd.read_csv('heart_desiase_dataset.csv')
df_hd
# Out:
#      Age  sex  cp trestbsp chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     63    1   4      140  260   0        1     112     1       3     2  ?
# 1     44    1   4      130  209   0        1     127     0       0     ?  ?
# 2     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 3     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 4     66    1   3      110  213   1        2      99     1     1.3     2  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 195   54    0   4      127  333   1        1     154     0       0     ?  ?
# 196   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 197   55    1   4      122  223   1        1     100     0       0     ?  ?
# 198   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 199   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    2
# 1      ?    0
# ...

# %%
df_hd.tail()
# Out:
#      Age  sex  cp trestbsp chol fbs  restecg thalach exang oldpeak slope ca  \
# 195   54    0   4      127  333   1        1     154     0       0     ?  ?
# 196   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 197   55    1   4      122  223   1        1     100     0       0     ?  ?
# 198   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 199   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 195    ?    1
# 196    ?    0
# 197    6    2
# 198    ?    0
# 199    ?    1

# %%
df_hd.shape
# Out:
# (200, 14)

# %%
df_hd.columns
# Out:
# Index(['Age', 'sex', 'cp', 'trestbsp', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %% [raw]
# 1. (age)     = Age in year
# 2. (sex)     = (1 = male; 0 = female)
# 3. (cp)      = chest pain type
# 4. (trestbps)= resting blood pressure (in mm Hg on admission to the hospital)
# 5. (chol)    = serum cholestoral in mg/dl
# 6. (fbs)     = (fasting blood sugar &gt; 120 mg/dl) (1 = true; 0 = false)
# 7. (restecg) = resting electrocardiographic results
# 8. (thalach) = maximum heart rate achieved
# 9. (exang)   = exercise induced angina (1 = yes; 0 = no)
# 10.(oldpeak) = ST depression induced by exercise relative to rest
# 11.(slope)   = the slope of the peak exercise ST segment
# 12.(ca)      = number of major vessels (0-3) colored by flourosopy
# 13.(thal)    = 3 = normal; 6 = fixed defect; 7 = reversable defect
# 14.(num)     = Target (the predicted attribute)

# %%
df_hd.dtypes
# Out:
# Age          int64
# sex          int64
# cp           int64
# trestbsp    object
# chol        object
# fbs         object
# restecg      int64
# thalach     object
# exang       object
# oldpeak     object
# slope       object
# ca          object
# thal        object
# num          int64
# dtype: object

# %% [markdown]
# Observation:
#
#     1. Dataset has 200 rows ,14 columns.
#
#     2. Age,sex,cp,num,restecg are int type rest of all flot type data types

# %%
df_hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       200 non-null    int64
#  1   sex       200 non-null    int64
#  2   cp        200 non-null    int64
#  3   trestbsp  200 non-null    object
#  4   chol      200 non-null    object
#  5   fbs       200 non-null    object
#  6   restecg   200 non-null    int64
#  7   thalach   200 non-null    object
#  8   exang     200 non-null    object
#  9   oldpeak   200 non-null    object
#  10  slope     200 non-null    object
#  11  ca        200 non-null    object
#  12  thal      200 non-null    object
#  13  num       200 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 22.0+ KB

# %% [markdown]
# Observation:
#
#     1. this function shows range index ,total number of columns,count and their respective datatypes.

# %% [markdown]
# # Statics summary

# %%
df_hd.describe()
# Out:
#               Age         sex          cp     restecg         num
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    59.350000    0.970000    3.505000    0.735000    1.520000
# std      7.811697    0.171015    0.795701    0.683455    1.219441
# min     35.000000    0.000000    1.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000    1.000000    1.000000
# 75%     64.000000    1.000000    4.000000    1.000000    3.000000
# max     77.000000    1.000000    4.000000    2.000000    4.000000

# %% [raw]
# observation:
#     1. max std = Age.

# %%
#Check the unique value and cont of object type.
for column in df_hd.columns:
        print(df_hd[column].unique())
        print(df_hd[column].value_counts())
        print('---------------------------------------')
# Out:
# [63 44 60 55 66 65 56 59 62 57 46 58 64 74 52 69 51 54 77 61 40 41 42 53
#  68 67 72 75 49 35 43 48 50 45 76 70 71 38 37]
# 63    15
# 62    15
# 55    14
# 60    12
# 58    12
# 61    12
# 57    10
# 64     9
# 56     9
# 69     8
# 59     8
# 54     7
# 51     7
# 65     6
# 74     5
# 67     5
# 53     5
# 68     4
# 48     4
# 72     3
# 66     3
# 75     3
# 40     2
# 46     2
# 50     2
# 49     2
# 41     2
# 52     2
# 71     2
# 42     1
# 37     1
# 38     1
# 77     1
# 43     1
# 44     1
# 45     1
# 76     1
# 70     1
# 35     1
# Name: Age, dtype: int64
# ---------------------------------------
# [1 0]
# 1    194
# 0      6
# Name: sex, dtype: int64
# ---------------------------------------
# [4 3 2 1]
# 4    131
# 3     47
# 2     14
# 1      8
# Name: cp, dtype: int64
# ---------------------------------------
# ['140' '130' '132' '142' '110' '120' '150' '180' '160' '126' '?' '128'
#  '170' '152' '116' '124' '0' '122' '144' '154' '125' '104' '136' '134'
# ...

# %% [raw]
# observation:

# %%
#check null values in dataset
df_hd.isnull().sum()
# Out:
# Age         0
# sex         0
# cp          0
# trestbsp    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#for more clearity build a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(df_hd.isnull())

# %% [raw]
#  There are null values present in dataset but not reflect in graph  so now replace '?' with 'NAN'.

# %%
#Replace ? to empty string 
df_hd.replace({'trestbsp': {'?' : np.nan}},regex=False,inplace=True)
df_hd.replace({'fbs': {'?' : np.nan}},regex=False,inplace=True)
df_hd.replace({'thalach': {'?' : np.nan}},regex=False,inplace=True)
df_hd.replace({'exang': {'?' : np.nan}},regex=False,inplace=True)
df_hd.replace({'oldpeak': {'?' : np.nan}},regex=False,inplace=True)
df_hd.replace({'ca': {'?' : np.nan}},regex=False,inplace=True)
df_hd.replace({'slope': {'?' : np.nan}},regex=False,inplace=True)
df_hd.replace({'thal': {'?' : np.nan}},regex=False,inplace=True)
df_hd.isnull().sum()
# Out:
# Age           0
# sex           0
# cp            0
# trestbsp     56
# chol          0
# fbs           7
# restecg       0
# thalach      53
# exang        53
# oldpeak      56
# slope       102
# ca          198
# thal        166
# num           0
# dtype: int64

# %%
#Build a heatmap for more clearity
plt.figure(figsize=(8,8))
sns.heatmap(df_hd.isnull())

# %% [markdown]
# # cleaning Data

# %%
#Column Slope,ca,thal have maximum null value so we can drop it.
df_hd_new =df_hd.drop(columns=['slope','ca','thal'])
df_hd_new
# Out:
#      Age  sex  cp trestbsp chol fbs  restecg thalach exang oldpeak  num
# 0     63    1   4      140  260   0        1     112     1       3    2
# 1     44    1   4      130  209   0        1     127     0       0    0
# 2     60    1   4      132  218   0        1     140     1     1.5    2
# 3     55    1   4      142  228   0        1     149     1     2.5    1
# 4     66    1   3      110  213   1        2      99     1     1.3    0
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...  ...
# 195   54    0   4      127  333   1        1     154     0       0    1
# 196   62    1   1      NaN  139   0        1     NaN   NaN     NaN    0
# 197   55    1   4      122  223   1        1     100     0       0    2
# 198   58    1   4      NaN  385   1        2     NaN   NaN     NaN    0
# 199   62    1   2      120  254   0        2      93     1       0    1
#
# [200 rows x 11 columns]

# %%
#Treated null values of columns 
from sklearn.impute import SimpleImputer

# create instance of imputer class
imp = SimpleImputer(strategy='mean')
df_hd_new['trestbsp']=imp.fit_transform(df_hd_new['restecg'].values.reshape(-1,1))
df_hd_new['restecg']=imp.fit_transform(df_hd_new['restecg'].values.reshape(-1,1))
df_hd_new['fbs']=imp.fit_transform(df_hd_new['fbs'].values.reshape(-1,1))
df_hd_new['thalach']=imp.fit_transform(df_hd_new['thalach'].values.reshape(-1,1))
df_hd_new['exang']=imp.fit_transform(df_hd_new['exang'].values.reshape(-1,1))
df_hd_new['oldpeak']=imp.fit_transform(df_hd_new['oldpeak'].values.reshape(-1,1))

#Again check null values
df_hd_new.isnull().sum()
# Out:
# Age         0
# sex         0
# cp          0
# trestbsp    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# num         0
# dtype: int64

# %%
sns.heatmap(df_hd_new.isnull())

# %% [raw]
# Observation:
#     Now No null value is Present in dataset

# %% [markdown]
# # Check the Correlation between variables

# %%
df_corr=df_hd_new.corr()
df_corr
# Out:
#                Age       sex        cp  trestbsp       fbs   restecg  \
# Age       1.000000  0.034230 -0.038280  0.002400  0.124753  0.002400
# sex       0.034230  1.000000  0.038036  0.060621 -0.055341  0.060621
# cp       -0.038280  0.038036  1.000000  0.034790 -0.047368  0.034790
# trestbsp  0.002400  0.060621  0.034790  1.000000  0.165927  1.000000
# fbs       0.124753 -0.055341 -0.047368  0.165927  1.000000  0.165927
# restecg   0.002400  0.060621  0.034790  1.000000  0.165927  1.000000
# thalach  -0.149949 -0.001592 -0.123597  0.012348  0.051405  0.012348
# exang     0.135050  0.016538  0.181907 -0.080575 -0.213312 -0.080575
# oldpeak   0.157087  0.097267  0.040155 -0.106991 -0.099321 -0.106991
# num       0.287289  0.147470  0.168210 -0.032800  0.050515 -0.032800
#
#            thalach     exang   oldpeak       num
# Age      -0.149949  0.135050  0.157087  0.287289
# sex      -0.001592  0.016538  0.097267  0.147470
# cp       -0.123597  0.181907  0.040155  0.168210
# ...

# %%
#For batter understanding Plot a heatmap of correlation metrix 
plt.figure(figsize=(10,8))
sns.heatmap(df_corr,annot=True, fmt='.0%')

# %% [raw]
# Observation:
#     1.

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(15,10))
lab = list(df_hd['num'].unique())
chart = sns.countplot(x="num",hue="num",data=df_hd_new)

# %%
plt.figure(figsize=(15,10))
lab = list(df_hd['sex'].unique())
chart = sns.countplot(x="sex",hue="sex",data=df_hd_new)

# %% [raw]
# Observation:
#
#     1. Number of male patients are more

# %%
plt.figure(figsize=(15,10))
lab = list(df_hd['Age'].unique())
chart = sns.countplot(x="Age",data=df_hd_new)

# %% [raw]
# Observation:
#
#     1. people of age of 61,62 are maximum suffering from heart-disease

# %%
plt.figure(figsize=(15,10))
lab = list(df_hd['cp'].unique())
chart = sns.countplot(x="cp",data=df_hd_new)

# %% [raw]
# Observation:
#
#     1. maximum chest Pain occurs in 4 type.

# %%
plt.figure(figsize=(15,10))
lab = list(df_hd['restecg'].unique())
chart = sns.countplot(x="restecg",data=df_hd_new)

# %% [raw]
# observation:
#
#     1.resting electrocardiographic results is maximum for 1.

# %% [markdown]
# # Bivariant Analysis

# %%
sns.set(style='white')
plt.scatter(df_hd['Age'],df_hd_new['num'])
plt.xlabel('Age')
plt.ylabel('num')
plt.title("Scatter plot Age vs num")
plt.show()

# %% [raw]
# observation:
#
#     1. Heart disease not present in age of 52 to 70 year pople.
#
#     2. 1 category heart disease max in age of <50 - >70.
#
#     3. 2 category heart disease max in age of < 50 - <65.

# %%
sns.set(style='white')
plt.scatter(df_hd['cp'],df_hd_new['Age'])
plt.xlabel('chest pain')
plt.ylabel('Age')
plt.title("Scatter plot chest Pain vs Age")

plt.show()

# %% [raw]
# Observation:
#
#     1. 3 type chest pain has maximum range.

# %%
sns.pairplot(df_hd_new,hue='num',size=2)

# %%
#All column histogram in one place
df_hd_new.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# # Plotting Outliers

# %%
df_hd_new.plot(kind='box',subplots=True,fontsize=8,figsize=(8,4))
# Out:
# Age            AxesSubplot(0.125,0.125;0.065678x0.755)
# sex         AxesSubplot(0.203814,0.125;0.065678x0.755)
# cp          AxesSubplot(0.282627,0.125;0.065678x0.755)
# trestbsp    AxesSubplot(0.361441,0.125;0.065678x0.755)
# fbs         AxesSubplot(0.440254,0.125;0.065678x0.755)
# restecg     AxesSubplot(0.519068,0.125;0.065678x0.755)
# thalach     AxesSubplot(0.597881,0.125;0.065678x0.755)
# exang       AxesSubplot(0.676695,0.125;0.065678x0.755)
# oldpeak     AxesSubplot(0.755508,0.125;0.065678x0.755)
# num         AxesSubplot(0.834322,0.125;0.065678x0.755)
# dtype: object

# %%
#check the distribution of skewness
for i in df_hd_new.describe().columns:
        plt.figure()
        sns.distplot(df_hd_new[i])

# %% [raw]
# Observation:
#
#     1. Left skewness in cp.
#
#     2. skewness in sex.

# %%
#checking Skewness of Data
df_hd_new.skew()
# Out:
# Age        -0.404091
# sex        -5.552105
# cp         -1.648734
# trestbsp    0.391463
# fbs         0.634130
# restecg     0.391463
# thalach     0.148515
# exang      -0.719015
# oldpeak     0.423414
# num         0.297393
# dtype: float64

# %%
#Again check skewness
df_hd_new.skew()
# Out:
# Age        -0.404091
# sex        -5.552105
# cp         -1.648734
# trestbsp    0.391463
# fbs         0.634130
# restecg     0.391463
# thalach     0.148515
# exang      -0.719015
# oldpeak     0.423414
# num         0.297393
# dtype: float64

# %%
#Transform the data (Transform non-numerical into numerical col)
from sklearn.preprocessing import LabelEncoder

for column in df_hd_new.columns:
    if df_hd_new[column].dtype == np.number:
        continue
    df_hd_new[column] = LabelEncoder().fit_transform(df_hd_new[column])

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df_hd_new))
z
# Out:
# array([[4.82657828e-01, 1.75863115e-01, 6.23653755e-01, ...,
#         8.62970996e-01, 1.79511750e+00, 3.94610899e-01],
#        [1.92061767e+00, 1.75863115e-01, 6.23653755e-01, ...,
#         1.57658163e+00, 1.41204031e+00, 1.24960118e+00],
#        [8.21119127e-02, 1.75863115e-01, 6.23653755e-01, ...,
#         8.62970996e-01, 1.91538592e-01, 3.94610899e-01],
#        ...,
#        [5.85464613e-01, 1.75863115e-01, 6.23653755e-01, ...,
#         1.57658163e+00, 1.41204031e+00, 3.94610899e-01],
#        [1.84918698e-01, 1.75863115e-01, 6.23653755e-01, ...,
#         0.00000000e+00, 2.37377363e-16, 1.24960118e+00],
#        [3.49142523e-01, 1.75863115e-01, 1.89615940e+00, ...,
#         8.62970996e-01, 1.41204031e+00, 4.27495141e-01]])

# %%
thershold=3
print(np.where(z<3))
# Out:
# (array([  0,   0,   0, ..., 199, 199, 199], dtype=int64), array([ 0,  1,  2, ...,  8,  9, 10], dtype=int64))

# %%
df_hd_final = df_hd_new[(z<3).all(axis=1)]
print(df_hd_new.shape, '\t',df_hd_final.shape)
# Out:
# (200, 11) 	 (184, 11)

# %% [raw]
# End of EDA Process.

# %% [markdown]
# # Model Trainning

# %%
#saprating into input and output variables

df_x= df_hd_final.drop(columns=['num'])
df_x.head()
# Out:
#    Age  sex  cp  trestbsp  chol  fbs  restecg  thalach  exang  oldpeak
# 0   25    1   3       1.0    62  0.0      1.0    112.0    1.0      3.0
# 1    7    1   3       1.0    28  0.0      1.0    127.0    0.0      0.0
# 2   22    1   3       1.0    35  0.0      1.0    140.0    1.0      1.5
# 3   17    1   3       1.0    45  0.0      1.0    149.0    1.0      2.5
# 4   28    1   2       2.0    31  1.0      2.0     99.0    1.0      1.3

# %%
y=pd.DataFrame(df_hd_final['num'])
y.head()
# Out:
#    num
# 0    2
# 1    0
# 2    2
# 3    1
# 4    0

# %%
#Scalling the input variable
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#check skewness
x.skew()
# Out:
# Age        -0.351275
# sex         0.000000
# cp         -1.381908
# trestbsp    0.383134
# chol        0.398938
# fbs         0.696006
# restecg     0.383134
# thalach    -0.063266
# exang      -0.797703
# oldpeak     0.433316
# dtype: float64

# %%
#Spliting The Data in Train and Target
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
print(x_train.shape, '\t', x_test.shape)
# Out:
# (128, 10) 	 (56, 10)

# %%
print(y_train.shape, '\t', y_test.shape)
# Out:
# (128, 1) 	 (56, 1)

# %%
#importing our Models library
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
#import Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
model=[KNeighborsClassifier(),DecisionTreeClassifier()]
for m in model:
    m.fit(x_train,y_train)
    print('Score of',m,'is:',m.score(x_train,y_train))
    predmodel=m.predict(x_test)
    print('Metrics')
    print('accuracy_score :',accuracy_score(y_test,predmodel))
    print('confusion_matrix :',confusion_matrix(y_test,predmodel))
    print('classification_report:',classification_report(y_test,predmodel))
    print('-----------------------------------------------------------')
    print('\n')
# Out:
# Score of KNeighborsClassifier() is: 0.5390625
# Metrics
# accuracy_score : 0.2857142857142857
# confusion_matrix : [[4 5 3 0 0]
#  [7 6 0 1 1]
#  [1 4 3 3 0]
#  [1 6 5 3 0]
#  [0 0 3 0 0]]
# classification_report:               precision    recall  f1-score   support
#
#            0       0.31      0.33      0.32        12
#            1       0.29      0.40      0.33        15
#            2       0.21      0.27      0.24        11
#            3       0.43      0.20      0.27        15
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.29        56
#    macro avg       0.25      0.24      0.23        56
# weighted avg       0.30      0.29      0.28        56
#
# -----------------------------------------------------------
#
#
# Score of DecisionTreeClassifier() is: 1.0
# Metrics
# accuracy_score : 0.375
# confusion_matrix : [[4 4 1 2 1]
#  [4 5 2 3 1]
#  [1 1 7 1 1]
#  [2 3 2 5 3]
#  [0 0 3 0 0]]
# ...

# %%
svr= SVR(kernel = "linear")
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
print('Score of',svr,'is:',svr.score(x_train,y_train))
predmodel = svr.predict(x_test)

svr= SVR(kernel = "poly")
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
print('Score of',svr,'is:',svr.score(x_train,y_train))
predmodel = svr.predict(x_test)

svr= SVR(kernel = "rbf")
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
print('Score of',svr,'is:',svr.score(x_train,y_train))
predmodel = svr.predict(x_test)
# Out:
# Score of SVR(kernel='linear') is: 0.16610909532684925
# Score of SVR(kernel='poly') is: 0.5134788236297678
# Score of SVR() is: 0.4716507122848915

# %% [raw]
# observation:
#
#     1. KNeighborsClassifier is best model.

# %%
#cross validation
from sklearn.model_selection import cross_val_score
kn = KNeighborsClassifier()
scores = cross_val_score(kn,x,y,cv=5).mean()
print(scores)
# Out:
# 0.3642642642642643

# %% [markdown]
# # Using Esemble Technique to Boostup Score

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=20,random_state=42)
rf.fit(x_train,y_train)
print('Score',rf.score(x_train,y_train))
rfpred=rf.predict(x_test)
print('\n')
print('accuracy_score :',accuracy_score(y_test,rfpred))
print('confusion_matrix :',confusion_matrix(y_test,rfpred))
print('classification_report:',classification_report(y_test,rfpred))
# Out:
# Score 1.0
#
#
# accuracy_score : 0.3392857142857143
# confusion_matrix : [[4 5 3 0 0]
#  [6 7 0 2 0]
#  [0 5 4 1 1]
#  [3 4 3 4 1]
#  [1 0 2 0 0]]
# classification_report:               precision    recall  f1-score   support
#
#            0       0.29      0.33      0.31        12
#            1       0.33      0.47      0.39        15
#            2       0.33      0.36      0.35        11
#            3       0.57      0.27      0.36        15
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.34        56
#    macro avg       0.30      0.29      0.28        56
# weighted avg       0.37      0.34      0.34        56

# %%
#cross validation
from sklearn.model_selection import cross_val_score
rf = RandomForestClassifier()
scores = cross_val_score(rf,x,y,cv=5).mean()
print(scores)
# Out:
# 0.34234234234234234
